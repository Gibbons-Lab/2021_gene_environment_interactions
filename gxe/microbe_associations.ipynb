# %% [markdown]
# # Identify bacterial genera associated with metabolites
#
# We will now select the microbes significantly associated with each metabolite. We will use the genus level here since that is usually the lowest taxonomic rank we can confidently identify with 16S amplicon sequencing.

# %%
import pandas as pd

train = pd.read_csv("data/train.csv")
valid = pd.read_csv("data/valid.csv")
abundance = pd.read_csv("/proj/arivale/microbiome/16S_processed/asvs.csv")
abundance["stool_sample_id"] = abundance.id.str.split("|").str[0]
abundance = abundance[abundance.stool_sample_id.isin(train.stool_sample_id) | abundance.stool_sample_id.isin(valid.stool_sample_id)]

taxonomy = pd.read_csv("/proj/arivale/microbiome/16S_processed/taxonomy.csv")
taxa_compact = taxonomy.Family + "|" + taxonomy.Genus
taxa_compact.index = taxonomy.id
abundance["taxon"] = taxa_compact[abundance.hash].values
genera = abundance.groupby(["stool_sample_id", "taxon"]).sum().reset_index()
genera.taxon.nunique()
# Out:
# 410

# %% [markdown]
# We also filter out genera that were not observed in at least 50% of all individuals and that have less than 10 detected reads per sample on average.

# %%
prevalence = genera.groupby("taxon").apply(lambda df: sum(df["count"] > 0)) / genera.stool_sample_id.nunique()
means = genera.groupby("taxon")["count"].mean()
good = (prevalence > 0.5) & (means > 10)
genera_filtered = genera[genera.taxon.isin(good.index[good])]
genera_filtered.taxon.nunique()
# Out:
# 82

# %% [markdown]
# Now we will CLR transform the abundances.

# %%
import numpy as np

def clr(x, pseudo):
    if pseudo == 0:
        out = x.copy()
        out[x == 0] = float("nan")
        out[x > 0] = np.log(x[x > 0]) - np.mean(np.log(x[x > 0])) 
    else:
        out = np.log(x + pseudo) - np.mean(np.log(x + pseudo))
    return out

genera_wide = pd.pivot_table(genera_filtered, index="stool_sample_id", columns="taxon", values="count", fill_value=0)
genera_wide_clr = genera_wide.apply(lambda x: clr(x, 1), axis=1)
genera_wide_clr.to_csv("data/genera_clr_filtered.csv")

genera_wide_clr_drop = genera_wide.apply(lambda x: clr(x, 0), axis=1)
genera_wide_clr_drop.to_csv("data/genera_clr_filtered_nonzero.csv")
genera_wide_clr.shape
# Out:
# (1569, 82)

# %%
metabolites_and_microbes = pd.merge(train, genera_wide_clr, left_on="stool_sample_id", right_index=True)

# %%
metabolites_and_microbes
# Out:
#      public_client_id      genome_id blood_sample_id  blood_days_in_program  \
# 0             1241633  A789AU958-007   A789AU992-002                   36.0
# 1             1020175      DS-268800   A430BH742-003                    8.0
# 2             1230573      DS-284622   A773BJ600-002                    4.0
# 3             1687802  A719AT743-004   A719AT785-002                   88.0
# 4             1864964      DS-267221   A862BF047-008                   14.0
# ..                ...            ...             ...                    ...
# 995           1035670      DS-269430   A808BG205-003                   33.0
# 996           1013950  A752AT594-004   A752AT607-002                   77.0
# 997           1244110  A939AV031-007   A473AS982-002                   52.0
# 998           1329753      DS-265707   A579BF997-003                    3.0
# 999           1028150      DS-268107   A202BI892-020                   30.0
#
#     stool_sample_id  stool_days_in_program sex   age  stool_vendor  \
# 0         AV15-1655                   36.0   M  71.0  SecondGenome
# 1    22001612561075                   13.0   F  41.0    DNAGenotek
# 2    22001701512104                   22.0   F  60.0    DNAGenotek
# 3         AV15-1320                   88.0   F  53.0  SecondGenome
# 4    22001612561843                   15.0   F  43.0    DNAGenotek
# ..              ...                    ...  ..   ...           ...
# 995  22001612562579                    9.0   F  33.0    DNAGenotek
# 996       AV15-1319                   77.0   F  42.0  SecondGenome
# 997       AV15-1143                   52.0   F  62.0  SecondGenome
# 998  22001612560465                   15.0   M  40.0    DNAGenotek
# 999  22001612562223                   25.0   M  57.0    DNAGenotek
#
#      WEIGHT_CALC  ...  Ruminococcaceae|Ruminococcaceae_UCG-014  \
# 0          179.0  ...                                -3.462865
# 1          192.8  ...                                -4.151371
# 2          152.0  ...                                -1.840533
# 3          242.0  ...                                -3.409260
# 4          170.0  ...                                -3.535311
# ..           ...  ...                                      ...
# 995        155.2  ...                                -5.483529
# 996        126.0  ...                                 3.016214
# 997        126.0  ...                                 2.807030
# 998        269.0  ...                                 2.352577
# 999        225.0  ...                                 2.794583
#
#     Ruminococcaceae|Ruminococcus_1 Ruminococcaceae|Ruminococcus_2  \
# 0                         3.690187                      -0.061668
# 1                         2.642095                      -4.151371
# 2                        -4.836265                      -4.836265
# 3                         3.829955                       3.229308
# 4                         4.653378                       1.226863
# ..                             ...                            ...
# 995                       4.261138                       3.655530
# 996                       2.118971                       4.178741
# 997                       1.858001                       2.510743
# 998                       3.215964                       3.505026
# 999                       4.623733                       3.963858
#
#      Ruminococcaceae|Subdoligranulum  Ruminococcaceae|UBA1819  \
# 0                           5.699964                 1.513869
# 1                           2.343894                 0.892054
# 2                          -4.836265                 0.436734
# 3                           1.300270                 0.598073
# 4                           2.005952                -0.762722
# ..                               ...                      ...
# 995                         4.293317                -0.608332
# 996                         3.622815                 0.170962
# 997                         1.855598                -2.277166
# 998                         3.807427                -3.081145
# 999                        -0.579437                 0.609202
#
#      Streptococcaceae|Lactococcus  Streptococcaceae|Streptococcus  \
# 0                       -1.265641                        2.477306
# 1                       -0.413702                        0.825362
# 2                       -1.122693                       -1.029603
# 3                        1.155088                        2.365292
# 4                       -3.535311                        0.942026
# ..                            ...                             ...
# 995                     -2.392487                        0.461891
# 996                     -5.147158                        2.745668
# 997                     -1.717550                        1.581457
# 998                     -3.081145                        0.870099
# 999                     -0.051369                        1.912690
#
#      Tannerellaceae|Parabacteroides  Veillonellaceae|Dialister  \
# 0                          1.506948                   4.792963
# 1                          5.826435                   3.427797
# 2                          3.860078                   3.405438
# 3                         -3.409260                  -3.409260
# 4                          4.230682                  -3.535311
# ..                              ...                        ...
# 995                        1.905417                   2.450267
# 996                        1.831056                  -5.147158
# 997                        1.387677                   2.798008
# 998                        1.429714                  -3.081145
# 999                        3.838356                   3.229638
#
#      Veillonellaceae|Veillonella
# 0                      -0.284811
# 1                      -1.015877
# 2                      -4.836265
# 3                       0.117101
# 4                      -0.827261
# ..                           ...
# 995                    -2.187693
# 996                    -5.147158
# 997                    -5.272898
# 998                    -3.081145
# 999                    -4.408078
#
# [1000 rows x 1030 columns]

# %%
from itertools import product
from rich.progress import track
from scipy.stats import pearsonr

mets = metabolites_and_microbes.columns[metabolites_and_microbes.columns.str.startswith("metabolite")]
mics = genera_wide_clr.columns

combinations = list(product(mets, mics))

metrics = pd.DataFrame(columns=["r", "p", "n"], dtype="float64", index=combinations)
formula = "{} ~ Q('{}')"
for comb in track(combinations):
    data = metabolites_and_microbes[list(comb)].dropna()
    ptest = pearsonr(data.iloc[:, 0], data.iloc[:, 1])
    metrics.loc[[comb], "r"] = ptest[0]
    metrics.loc[[comb], "p"] = ptest[1]
    metrics.loc[[comb], "n"] = data.shape[0]
# Out:
# Output()

# %%
from statsmodels.stats.multitest import fdrcorrection

metrics["q"] = fdrcorrection(metrics.p)[1]
metrics["r2"] = metrics.r.pow(2)
metrics["metabolite"] = metrics.index.map(lambda x: x[0])
metrics["taxon"] = metrics.index.map(lambda x: x[1])

# %%
metrics.sort_values(by="p").head(100)
# Out:
#                                                            r             p  \
# (metabolite_100002253, Family_XIII|Family_XIII_...  0.508087  5.617983e-60
# (metabolite_100002488, Ruminococcaceae|Ruminoco... -0.476256  7.957527e-54
# (metabolite_100002488, Ruminococcaceae|Flavonif...  0.475678  1.108531e-53
# (metabolite_100002488, Lachnospiraceae|Lachnocl...  0.468988  4.900222e-52
# (metabolite_100000010, Family_XIII|Family_XIII_...  0.442081  4.059205e-43
# ...                                                      ...           ...
# (metabolite_100020536, Lachnospiraceae|Lachnocl... -0.272563  9.977384e-17
# (metabolite_100001417, Lachnospiraceae|Lachnosp... -0.265274  1.484930e-16
# (metabolite_100001083, Erysipelotrichaceae|Erys... -0.263484  1.863074e-16
# (metabolite_100000014, Ruminococcaceae|Ruminoco...  0.260556  2.574030e-16
# (metabolite_100000010, Lachnospiraceae|Sellimonas) -0.271929  2.783801e-16
#
#                                                         n             q  \
# (metabolite_100002253, Family_XIII|Family_XIII_...  896.0  4.284274e-55
# (metabolite_100002488, Ruminococcaceae|Ruminoco...  930.0  2.817885e-49
# (metabolite_100002488, Ruminococcaceae|Flavonif...  930.0  2.817885e-49
# (metabolite_100002488, Lachnospiraceae|Lachnocl...  930.0  9.342274e-48
# (metabolite_100000010, Family_XIII|Family_XIII_...  874.0  6.191099e-39
# ...                                                   ...           ...
# (metabolite_100020536, Lachnospiraceae|Lachnocl...  896.0  7.925785e-14
# (metabolite_100001417, Lachnospiraceae|Lachnosp...  937.0  1.167431e-13
# (metabolite_100001083, Erysipelotrichaceae|Erys...  944.0  1.449776e-13
# (metabolite_100000014, Ruminococcaceae|Ruminoco...  957.0  1.982783e-13
# (metabolite_100000010, Lachnospiraceae|Sellimonas)  874.0  2.122926e-13
#
#                                                           r2  \
# (metabolite_100002253, Family_XIII|Family_XIII_...  0.258152
# (metabolite_100002488, Ruminococcaceae|Ruminoco...  0.226820
# (metabolite_100002488, Ruminococcaceae|Flavonif...  0.226270
# (metabolite_100002488, Lachnospiraceae|Lachnocl...  0.219949
# (metabolite_100000010, Family_XIII|Family_XIII_...  0.195436
# ...                                                      ...
# (metabolite_100020536, Lachnospiraceae|Lachnocl...  0.074291
# (metabolite_100001417, Lachnospiraceae|Lachnosp...  0.070370
# (metabolite_100001083, Erysipelotrichaceae|Erys...  0.069424
# (metabolite_100000014, Ruminococcaceae|Ruminoco...  0.067889
# (metabolite_100000010, Lachnospiraceae|Sellimonas)  0.073945
#
#                                                               metabolite  \
# (metabolite_100002253, Family_XIII|Family_XIII_...  metabolite_100002253
# (metabolite_100002488, Ruminococcaceae|Ruminoco...  metabolite_100002488
# (metabolite_100002488, Ruminococcaceae|Flavonif...  metabolite_100002488
# (metabolite_100002488, Lachnospiraceae|Lachnocl...  metabolite_100002488
# (metabolite_100000010, Family_XIII|Family_XIII_...  metabolite_100000010
# ...                                                                  ...
# (metabolite_100020536, Lachnospiraceae|Lachnocl...  metabolite_100020536
# (metabolite_100001417, Lachnospiraceae|Lachnosp...  metabolite_100001417
# (metabolite_100001083, Erysipelotrichaceae|Erys...  metabolite_100001083
# (metabolite_100000014, Ruminococcaceae|Ruminoco...  metabolite_100000014
# (metabolite_100000010, Lachnospiraceae|Sellimonas)  metabolite_100000010
#
#                                                                                             taxon
# (metabolite_100002253, Family_XIII|Family_XIII_...                Family_XIII|Family_XIII_UCG-001
# (metabolite_100002488, Ruminococcaceae|Ruminoco...  Ruminococcaceae|Ruminococcaceae_NK4A214_group
# (metabolite_100002488, Ruminococcaceae|Flavonif...                 Ruminococcaceae|Flavonifractor
# (metabolite_100002488, Lachnospiraceae|Lachnocl...              Lachnospiraceae|Lachnoclostridium
# (metabolite_100000010, Family_XIII|Family_XIII_...                Family_XIII|Family_XIII_UCG-001
# ...                                                                                           ...
# (metabolite_100020536, Lachnospiraceae|Lachnocl...              Lachnospiraceae|Lachnoclostridium
# (metabolite_100001417, Lachnospiraceae|Lachnosp...        Lachnospiraceae|Lachnospiraceae_UCG-004
# (metabolite_100001083, Erysipelotrichaceae|Erys...     Erysipelotrichaceae|Erysipelatoclostridium
# (metabolite_100000014, Ruminococcaceae|Ruminoco...        Ruminococcaceae|Ruminococcaceae_UCG-002
# (metabolite_100000010, Lachnospiraceae|Sellimonas)                     Lachnospiraceae|Sellimonas
#
# [100 rows x 7 columns]

# %%
metrics[metrics.q < 0.05].to_csv("data/sig_metabolite_taxon.csv", index=False)

# %%
metrics[metrics.q < 0.05].metabolite.nunique()
# Out:
# 508
